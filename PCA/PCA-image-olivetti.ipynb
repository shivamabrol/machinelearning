# %%
from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
oliv = datasets.fetch_olivetti_faces()
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to C:\Users\shivam.abrol\scikit_learn_data

# %%
oliv.images.shape
# Out:
# (400, 64, 64)

# %%
fig = plt.figure(figsize = (8, 8))
for i in range(64):
    ax = fig.add_subplot(8, 8, i + 1)
    ax.imshow(oliv.images[i], cmap = plt.cm.bone)
plt.show()

# %%
pca = PCA()
pca.fit(oliv.data)
# Out:
# PCA()

# %%
pca.explained_variance_.shape
# Out:
# (400,)

# %%
total = pca.explained_variance_.sum()
current_var = 0
k = 0
while current_var/total < 0.95:
    current_var += pca.explained_variance_[k]
    k += 1
k
# Out:
# 123

# %%
pca = PCA(n_components = k)
pca.fit(oliv.data)
# Out:
# PCA(n_components=123)

# %%
eignen_faces = pca.components_.reshape((-1, 64, 64))

# %%
fig = plt.figure(figsize = (8, 8))
for i in range(64):
    ax = fig.add_subplot(8, 8, i + 1)
    ax.imshow(eignen_faces[i], cmap = plt.cm.bone)
plt.show()
